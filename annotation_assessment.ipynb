# %%
#use this
from PIL import Image
import PIL.ImageOps  
import numpy as np
import os
import cv2
import csv
Image.MAX_IMAGE_PIXELS = None
from tqdm import tqdm

def show(arr):
    im = Image.fromarray(np.array(255*arr/np.max(arr),dtype=np.uint8))
    im.show()

def getcentre(contours):
    M = cv2.moments(contours)
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
    return((cX,cY))

def drawcentres(img_msk_blend, arr,contours,labels=[],ptrad=3):
    '''Modified function from mitocyto to write number and centres on contours'''
    rgb = img_msk_blend
    h,w = arr.shape
    uselabs = True 
    
    for i,cnt in enumerate(contours):
        cX,cY = getcentre(cnt)
        cv2.circle(rgb, (cX,cY), ptrad, (255, 0, 0), -1)
        if uselabs and arr.shape[1]>100:
            cv2.putText(rgb, str(i), (min(w-10,max(10,cX - 20)), min(h-10,max(10,cY - 10))),cv2.FONT_HERSHEY_SIMPLEX, 0.5*arr.shape[1]/2656.0, (255, 255, 255), 1)
          
    return(rgb)

def get_over_the_border_area(img, annarr, element_size = 2):   # set element size to 2 for IMC and 6 for QIF images
    '''Function that returns results: list with all our metrics and fibre number, and contours'''
    
    annarr[0,:-1] = annarr[:-1,-1] = annarr[-1,::-1] = annarr[-2:0:-1,0] = annarr.max()

    # Find fibres from annotation
    contours,hierarchy = cv2.findContours(annarr, cv2.RETR_CCOMP,2)
    # Ensure only looking at holes inside contours...
    contours = [c for i,c in enumerate(contours) if hierarchy[0][i][3] != -1]
                                          
    # Element for erosion/dilation
    element = cv2.getStructuringElement(cv2.MORPH_RECT, (2 * element_size + 1, 2 * element_size + 1),
                                        (element_size, element_size))

       
    results = [] 
    for i,contour in enumerate(tqdm((contours), desc='Contours processed')):
        black = np.zeros(annarr.shape,dtype=np.uint8)
        cv2.drawContours(black,[contour], -1, (255), -1)
        edge_eroded = black - cv2.erode(black,element) # area to check for dystrophin +ve
        edge_dilated = cv2.dilate(black,element) - black  # area to check for VDAC +ve
        
        # calculating pixels in three area 1) dilated area 2) eroded area and 3) fibre area - eroded area
        outer_pixels = edge_dilated == 255
        inner_pixels = edge_eroded == 255
        fibre_pixels = black == 255
        check_area = outer_pixels + inner_pixels
        #show(check_area)
        #show(inner_pixels)

        # THERSHOLD .85 & .75 for QIF
        membrane_thresh = img[:,:,2] > np.quantile(img[:,:,2],0.85)
        mito_mass_thresh = img[:,:,1] > np.quantile(img[:,:,1],0.75)
        #show(mito_mass_thresh)
        #show(membrane_thresh)
        
        # calculating red(dystophin) and green(VDAC) pixels in appropriate areas
        membrane_included = np.logical_and(membrane_thresh, inner_pixels)
        mito_mass_missed = np.logical_and(mito_mass_thresh, outer_pixels)
        membrane_in_fibre = np.logical_and(membrane_thresh, fibre_pixels)
        
        # calculating proportions
        proportion_membrane_included = (np.sum(membrane_included)/np.sum(outer_pixels))*100
        proportion_mito_mass_missed = (np.sum(mito_mass_missed)/np.sum(inner_pixels))*100
        proportion_membrane_in_fibre = (np.sum(membrane_in_fibre)/np.sum(fibre_pixels))*100
        
        values = [i,proportion_membrane_included,proportion_mito_mass_missed,proportion_membrane_in_fibre]
        results.append(values)
        
        
    
    return(results,contours)

def are_same_fibres(cont1, cont2):
    c1X,c1Y = getcentre(cont1)
    #c2X,c2Y = getcentre(cont2)
    dist = cv2.pointPolygonTest(cont2,(c1X,c1Y),True) # checking if centre of first contour exist in second contour
    if dist > 0:
        val = True
    else:
        val = False
    return val

def IoU_two_contours(ann,cont1, cont2):
    contours = [cont1, cont2]

        # Create image filled with zeros the same size of original image
    blank = np.zeros(ann.shape[0:2])

        # Copy each contour into its own image and fill it with '1'
    image1 = cv2.drawContours(blank.copy(), contours, 0, 255,thickness = cv2.FILLED) # 0 index contour i.e. first one
    image2 = cv2.drawContours(blank.copy(), contours, 1, 255,thickness = cv2.FILLED) # 1 index contour i.e. second one

        # Use the logical AND operation on the two images
        # Since the two images had bitwise and applied to it,
        # there should be a '1' or 'True' where there was intersection
        # and a '0' or 'False' where it didnt intersect
    intersection = np.logical_and(image1, image2)
    union = np.logical_or(image1, image2)
    IoU = np.sum(intersection)/np.sum(union)    
    img_msk_blend = cv2.merge((blank, image1, image2))      
    return IoU, img_msk_blend

def IoU_score (annarr, mask1, mask2):
    
    annarr[0,:-1] = annarr[:-1,-1] = annarr[-1,::-1] = annarr[-2:0:-1,0] = annarr.max()
    mask1[0,:-1] = mask1[:-1,-1] = mask1[-1,::-1] = mask1[-2:0:-1,0] = mask1.max()
    mask2[0,:-1] = mask2[:-1,-1] = mask2[-1,::-1] = mask2[-2:0:-1,0] = mask2.max()
    # Find fibres from mask1
    contours1,hierarchy1 = cv2.findContours(mask1, cv2.RETR_CCOMP,2)
    # Ensure only looking at holes inside contours...
    contours1 = [c for i,c in enumerate(contours1) if hierarchy1[0][i][3] != -1]
    
    # Find fibres from mask2
    contours2,hierarchy2 = cv2.findContours(mask2, cv2.RETR_CCOMP,2)
    # Ensure only looking at holes inside contours...
    contours2 = [c for i,c in enumerate(contours2) if hierarchy2[0][i][3] != -1]                                      
    
    
    
    blend_images =[] # stores images of contours overlapping
    results = [] 
    for i,contour in enumerate(tqdm((contours1), desc='Contours processed')):
        for j, cont in enumerate(contours2):
            
            val = are_same_fibres(contours1[i],contours2[j])
            if val:
                IoU, img_blend = IoU_two_contours(annarr,contours1[i], contours2[j])
                values = [i,j,IoU]
                results.append(values)
                blend_images.append(img_blend)
    return results, blend_images
                
                
            
    

inp_img_dir = './images'   # directory with orginal images to be annotated
inp_msk_dir = './masks'   # directory with annotation mask done by Apeer
inp_our_msk_dir = './ourMasks'# directory with annotation mask done by us
out_dir = './outputs'# output directory


img_list = [f for f in
            os.listdir(inp_img_dir)
            if os.path.isfile(os.path.join(inp_img_dir, f))]

for infile in img_list:
    infile_img_path = os.path.join(inp_img_dir, infile)
    infile_msk_path = os.path.join(inp_msk_dir, infile.split('.')[0] + '.tif')
    infile_msk_our_path = os.path.join(inp_our_msk_dir, infile.split('.')[0] + '.png')
    infile_out_path = os.path.join(out_dir, infile.split('.')[0] + '.csv')
    infile_out_path_IoU = os.path.join(out_dir, infile.split('.')[0] + '_IoU.csv')
    infile_out_path_img = os.path.join(out_dir, infile.split('.')[0] + '.tif')
   
    img = cv2.imread(infile_img_path)
    mask = cv2.imread(infile_msk_path,0)
    mask_our = cv2.imread(infile_msk_our_path,0)
    
    annarr = np.array(mask,dtype=np.uint8)
    thresh,annarr = cv2.threshold(annarr, 0, 255, cv2.THRESH_BINARY)
    # inverting binary mask so as to have white pixels as annotations
    annarr_invert = (255-annarr)

    # Adding mask as blue channel. Fine.  But what about when have nuclear signal in blue channel?
    img_msk_blend = cv2.merge((annarr_invert, cv2.split(img)[1], cv2.split(img)[2]))
    
    # getting membrane included and mass missed metrics
    results_metrics,contours = get_over_the_border_area(img, mask)
    
    # getting IoU between our and Apeer annotations
    results_IoU, blend_images = IoU_score (annarr, mask, mask_our)
   
    # identifying the contours
    result_img=drawcentres(img_msk_blend, mask, contours)
    cv2.imwrite(infile_out_path_img, result_img)
    
    # saving images of all IOU contours
    for i, img in enumerate(blend_images):
        path = os.path.join(out_dir, infile.split('.')[0] + '_'+ str(i)+'_.png')
        cv2.imwrite(path, img)
    
   
    header = ['FibreNumber','proportion_membrane_included', 'proportion_mito_mass_missed', 'proportion_membrane']
   
    with open(infile_out_path, "w", encoding="UTF8",newline='') as f:
        writer = csv.writer(f)
        # write the header
        writer.writerow(header)
        # write the data
        writer.writerows(results_metrics)
    
    header1 = ['FibreApeer','FibreUs', 'IoU Score']
    with open(infile_out_path_IoU, "w", encoding="UTF8",newline='') as f:
        writer = csv.writer(f)
        # write the header
        writer.writerow(header1)
        # write the data
        writer.writerows(results_IoU)
# Out:
# Contours processed:   0%|          | 0/1876 [00:00<?, ?it/s]
# Contours processed:   0%|          | 1/1876 [00:00<08:17,  3.77it/s]
# Contours processed:   0%|          | 2/1876 [00:00<08:19,  3.75it/s]
# Contours processed:   0%|          | 3/1876 [00:00<08:34,  3.64it/s]
# Contours processed:   0%|          | 4/1876 [00:01<08:37,  3.62it/s]
# Contours processed:   0%|          | 5/1876 [00:01<08:31,  3.66it/s]
# Contours processed:   0%|          | 6/1876 [00:01<08:31,  3.66it/s]
# Contours processed:   0%|          | 7/1876 [00:01<08:29,  3.67it/s]
# Contours processed:   0%|          | 8/1876 [00:02<08:29,  3.67it/s]
# Contours processed:   0%|          | 9/1876 [00:02<08:28,  3.67it/s]
# Contours processed:   1%|          | 10/1876 [00:02<08:31,  3.65it/s]
# Contours processed:   1%|          | 11/1876 [00:03<08:44,  3.55it/s]
# Contours processed:   1%|          | 12/1876 [00:03<08:39,  3.59it/s]
# Contours processed:   1%|          | 13/1876 [00:03<08:36,  3.60it/s]
# Contours processed:   1%|          | 14/1876 [00:03<08:33,  3.63it/s]
# Contours processed:   1%|          | 15/1876 [00:04<08:32,  3.63it/s]
# Contours processed:   1%|          | 16/1876 [00:04<08:33,  3.62it/s]
# Contours processed:   1%|          | 17/1876 [00:04<08:31,  3.63it/s]
# Contours processed:   1%|          | 18/1876 [00:04<08:28,  3.66it/s]
# Contours processed:   1%|          | 19/1876 [00:05<08:39,  3.57it/s]
# Contours processed:   1%|          | 20/1876 [00:05<08:51,  3.49it/s]
# Contours processed:   1%|          | 21/1876 [00:05<08:53,  3.47it/s]
# Contours processed:   1%|          | 22/1876 [00:06<08:46,  3.52it/s]
# Contours processed:   1%|          | 23/1876 [00:06<08:42,  3.55it/s]
# Contours processed:   1%|▏         | 24/1876 [00:06<08:38,  3.57it/s]
# Contours processed:   1%|▏         | 25/1876 [00:06<08:33,  3.60it/s]
# Contours processed:   1%|▏         | 26/1876 [00:07<08:30,  3.63it/s]
# Contours processed:   1%|▏         | 27/1876 [00:07<08:26,  3.65it/s]
# Contours processed:   1%|▏         | 28/1876 [00:07<08:28,  3.63it/s]
# Contours processed:   2%|▏         | 29/1876 [00:08<08:25,  3.66it/s]
# Contours processed:   2%|▏         | 30/1876 [00:08<08:27,  3.64it/s]
# Contours processed:   2%|▏         | 31/1876 [00:08<08:24,  3.66it/s]
# Contours processed:   2%|▏         | 32/1876 [00:08<08:24,  3.66it/s]
# Contours processed:   2%|▏         | 33/1876 [00:09<08:26,  3.64it/s]
# Contours processed:   2%|▏         | 34/1876 [00:09<08:23,  3.66it/s]
# Contours processed:   2%|▏         | 35/1876 [00:09<08:25,  3.64it/s]
# Contours processed:   2%|▏         | 36/1876 [00:09<08:22,  3.66it/s]
# Contours processed:   2%|▏         | 37/1876 [00:10<08:21,  3.66it/s]
# Contours processed:   2%|▏         | 38/1876 [00:10<08:21,  3.67it/s]
# Contours processed:   2%|▏         | 39/1876 [00:10<08:23,  3.65it/s]
# Contours processed:   2%|▏         | 40/1876 [00:11<08:24,  3.64it/s]
# Contours processed:   2%|▏         | 41/1876 [00:11<08:22,  3.65it/s]
# Contours processed:   2%|▏         | 42/1876 [00:11<08:36,  3.55it/s]
# Contours processed:   2%|▏         | 43/1876 [00:11<08:33,  3.57it/s]
# Contours processed:   2%|▏         | 44/1876 [00:12<08:29,  3.60it/s]
# Contours processed:   2%|▏         | 45/1876 [00:12<08:27,  3.61it/s]
# Contours processed:   2%|▏         | 46/1876 [00:12<08:34,  3.56it/s]
# Contours processed:   3%|▎         | 47/1876 [00:13<08:31,  3.58it/s]
# Contours processed:   3%|▎         | 48/1876 [00:13<08:28,  3.60it/s]
# Contours processed:   3%|▎         | 49/1876 [00:13<08:25,  3.61it/s]
# Contours processed:   3%|▎         | 50/1876 [00:13<08:22,  3.64it/s]
# Contours processed:   3%|▎         | 51/1876 [00:14<08:19,  3.66it/s]
# Contours processed:   3%|▎         | 52/1876 [00:14<08:18,  3.66it/s]
# Contours processed:   3%|▎         | 53/1876 [00:14<08:26,  3.60it/s]
# Contours processed:   3%|▎         | 54/1876 [00:14<08:42,  3.49it/s]
# Contours processed:   3%|▎         | 55/1876 [00:15<08:40,  3.50it/s]
# Contours processed:   3%|▎         | 56/1876 [00:15<08:45,  3.46it/s]
# Contours processed:   3%|▎         | 57/1876 [00:15<08:55,  3.40it/s]
# Contours processed:   3%|▎         | 58/1876 [00:16<08:42,  3.48it/s]
# Contours processed:   3%|▎         | 59/1876 [00:16<08:53,  3.41it/s]
# Contours processed:   3%|▎         | 60/1876 [00:16<08:46,  3.45it/s]
# Contours processed:   3%|▎         | 61/1876 [00:16<08:43,  3.46it/s]
# Contours processed:   3%|▎         | 62/1876 [00:17<08:54,  3.39it/s]
# Contours processed:   3%|▎         | 63/1876 [00:17<08:42,  3.47it/s]
# Contours processed:   3%|▎         | 64/1876 [00:17<08:35,  3.51it/s]
# Contours processed:   3%|▎         | 65/1876 [00:18<08:30,  3.55it/s]
# Contours processed:   4%|▎         | 66/1876 [00:18<08:24,  3.58it/s]
# Contours processed:   4%|▎         | 67/1876 [00:18<08:23,  3.59it/s]
# Contours processed:   4%|▎         | 68/1876 [00:18<08:23,  3.59it/s]
# Contours processed:   4%|▎         | 69/1876 [00:19<08:19,  3.62it/s]
# Contours processed:   4%|▎         | 70/1876 [00:19<08:16,  3.64it/s]
# Contours processed:   4%|▍         | 71/1876 [00:19<08:28,  3.55it/s]
# Contours processed:   4%|▍         | 72/1876 [00:20<08:31,  3.52it/s]
# Contours processed:   4%|▍         | 73/1876 [00:20<08:36,  3.49it/s]
# Contours processed:   4%|▍         | 74/1876 [00:20<08:46,  3.42it/s]
# Contours processed:   4%|▍         | 75/1876 [00:20<08:52,  3.38it/s]
# Contours processed:   4%|▍         | 76/1876 [00:21<09:05,  3.30it/s]
# Contours processed:   4%|▍         | 77/1876 [00:21<09:22,  3.20it/s]
# Contours processed:   4%|▍         | 78/1876 [00:21<09:23,  3.19it/s]
# Contours processed:   4%|▍         | 79/1876 [00:22<09:04,  3.30it/s]
# Contours processed:   4%|▍         | 80/1876 [00:22<08:46,  3.41it/s]
# Contours processed:   4%|▍         | 81/1876 [00:22<08:37,  3.47it/s]
# Contours processed:   4%|▍         | 82/1876 [00:23<08:31,  3.51it/s]
# Contours processed:   4%|▍         | 83/1876 [00:23<08:23,  3.56it/s]
# Contours processed:   4%|▍         | 84/1876 [00:23<08:19,  3.59it/s]
# Contours processed:   5%|▍         | 85/1876 [00:23<08:18,  3.59it/s]
# Contours processed:   5%|▍         | 86/1876 [00:24<08:15,  3.61it/s]
# Contours processed:   5%|▍         | 87/1876 [00:24<08:17,  3.60it/s]
# Contours processed:   5%|▍         | 88/1876 [00:24<08:15,  3.61it/s]
# Contours processed:   5%|▍         | 89/1876 [00:24<08:13,  3.62it/s]
# Contours processed:   5%|▍         | 90/1876 [00:25<08:14,  3.61it/s]
# Contours processed:   5%|▍         | 91/1876 [00:25<08:12,  3.63it/s]
# Contours processed:   5%|▍         | 92/1876 [00:25<08:13,  3.62it/s]
# Contours processed:   5%|▍         | 93/1876 [00:26<08:09,  3.64it/s]
# Contours processed:   5%|▌         | 94/1876 [00:26<08:08,  3.65it/s]
# Contours processed:   5%|▌         | 95/1876 [00:26<08:09,  3.64it/s]
# Contours processed:   5%|▌         | 96/1876 [00:26<08:10,  3.63it/s]
# Contours processed:   5%|▌         | 97/1876 [00:27<08:07,  3.65it/s]
# Contours processed:   5%|▌         | 98/1876 [00:27<08:05,  3.66it/s]
# Contours processed:   5%|▌         | 99/1876 [00:27<08:04,  3.67it/s]
# Contours processed:   5%|▌         | 100/1876 [00:28<08:07,  3.64it/s]
# Contours processed:   5%|▌         | 101/1876 [00:28<08:08,  3.64it/s]
# Contours processed:   5%|▌         | 102/1876 [00:28<08:05,  3.66it/s]
# Contours processed:   5%|▌         | 103/1876 [00:28<08:04,  3.66it/s]
# Contours processed:   6%|▌         | 104/1876 [00:29<08:05,  3.65it/s]
# Contours processed:   6%|▌         | 105/1876 [00:29<08:03,  3.66it/s]
# Contours processed:   6%|▌         | 106/1876 [00:29<08:05,  3.64it/s]
# Contours processed:   6%|▌         | 107/1876 [00:29<08:05,  3.64it/s]
# Contours processed:   6%|▌         | 108/1876 [00:30<08:06,  3.64it/s]
# Contours processed:   6%|▌         | 109/1876 [00:30<08:04,  3.65it/s]
# Contours processed:   6%|▌         | 110/1876 [00:30<08:02,  3.66it/s]
# Contours processed:   6%|▌         | 111/1876 [00:31<08:04,  3.64it/s]
# Contours processed:   6%|▌         | 112/1876 [00:31<08:03,  3.65it/s]
# Contours processed:   6%|▌         | 113/1876 [00:31<08:03,  3.64it/s]
# Contours processed:   6%|▌         | 114/1876 [00:31<08:03,  3.65it/s]
# Contours processed:   6%|▌         | 115/1876 [00:32<07:59,  3.67it/s]
# Contours processed:   6%|▌         | 116/1876 [00:32<07:58,  3.68it/s]
# Contours processed:   6%|▌         | 117/1876 [00:32<07:57,  3.69it/s]
# Contours processed:   6%|▋         | 118/1876 [00:32<07:55,  3.70it/s]
# Contours processed:   6%|▋         | 119/1876 [00:33<07:53,  3.71it/s]
# Contours processed:   6%|▋         | 120/1876 [00:33<07:53,  3.71it/s]
# Contours processed:   6%|▋         | 121/1876 [00:33<08:10,  3.58it/s]
# Contours processed:   7%|▋         | 122/1876 [00:34<08:10,  3.57it/s]
# Contours processed:   7%|▋         | 123/1876 [00:34<08:06,  3.61it/s]
# Contours processed:   7%|▋         | 124/1876 [00:34<08:02,  3.63it/s]
# Contours processed:   7%|▋         | 125/1876 [00:34<08:01,  3.64it/s]
# Contours processed:   7%|▋         | 126/1876 [00:35<07:56,  3.67it/s]
# Contours processed:   7%|▋         | 127/1876 [00:35<07:52,  3.70it/s]
# Contours processed:   7%|▋         | 128/1876 [00:35<07:53,  3.69it/s]
# Contours processed:   7%|▋         | 129/1876 [00:35<07:53,  3.69it/s]
# Contours processed:   7%|▋         | 130/1876 [00:36<07:50,  3.71it/s]
# Contours processed:   7%|▋         | 131/1876 [00:36<07:49,  3.71it/s]
# Contours processed:   7%|▋         | 132/1876 [00:36<07:49,  3.72it/s]
# Contours processed:   7%|▋         | 133/1876 [00:37<07:51,  3.70it/s]
# Contours processed:   7%|▋         | 134/1876 [00:37<08:01,  3.62it/s]
# Contours processed:   7%|▋         | 135/1876 [00:37<08:08,  3.57it/s]
# Contours processed:   7%|▋         | 136/1876 [00:37<08:07,  3.57it/s]
# Contours processed:   7%|▋         | 137/1876 [00:38<08:01,  3.61it/s]
# Contours processed:   7%|▋         | 138/1876 [00:38<07:58,  3.63it/s]
# Contours processed:   7%|▋         | 139/1876 [00:38<07:55,  3.65it/s]
# Contours processed:   7%|▋         | 140/1876 [00:38<07:53,  3.67it/s]
# Contours processed:   8%|▊         | 141/1876 [00:39<07:51,  3.68it/s]
# Contours processed:   8%|▊         | 142/1876 [00:39<07:48,  3.70it/s]
# Contours processed:   8%|▊         | 143/1876 [00:39<07:49,  3.69it/s]
# Contours processed:   8%|▊         | 144/1876 [00:40<07:48,  3.70it/s]
# Contours processed:   8%|▊         | 145/1876 [00:40<07:48,  3.70it/s]
# Contours processed:   8%|▊         | 146/1876 [00:40<07:46,  3.71it/s]
# Contours processed:   8%|▊         | 147/1876 [00:40<07:46,  3.71it/s]
# Contours processed:   8%|▊         | 148/1876 [00:41<07:44,  3.72it/s]
# Contours processed:   8%|▊         | 149/1876 [00:41<07:51,  3.66it/s]
# Contours processed:   8%|▊         | 150/1876 [00:41<07:49,  3.68it/s]
# Contours processed:   8%|▊         | 151/1876 [00:41<07:48,  3.68it/s]
# Contours processed:   8%|▊         | 152/1876 [00:42<07:48,  3.68it/s]
# Contours processed:   8%|▊         | 153/1876 [00:42<07:47,  3.69it/s]
# Contours processed:   8%|▊         | 154/1876 [00:42<07:46,  3.69it/s]
# Contours processed:   8%|▊         | 155/1876 [00:43<07:47,  3.68it/s]
# Contours processed:   8%|▊         | 156/1876 [00:43<07:46,  3.68it/s]
# Contours processed:   8%|▊         | 157/1876 [00:43<07:46,  3.68it/s]
# Contours processed:   8%|▊         | 158/1876 [00:43<07:51,  3.64it/s]
# Contours processed:   8%|▊         | 159/1876 [00:44<07:49,  3.66it/s]
# Contours processed:   9%|▊         | 160/1876 [00:44<07:47,  3.67it/s]
# Contours processed:   9%|▊         | 161/1876 [00:44<07:46,  3.67it/s]
# Contours processed:   9%|▊         | 162/1876 [00:44<07:46,  3.67it/s]
# Contours processed:   9%|▊         | 163/1876 [00:45<07:44,  3.68it/s]
# Contours processed:   9%|▊         | 164/1876 [00:45<07:43,  3.69it/s]
# Contours processed:   9%|▉         | 165/1876 [00:45<07:43,  3.69it/s]
# Contours processed:   9%|▉         | 166/1876 [00:46<07:46,  3.66it/s]
# Contours processed:   9%|▉         | 167/1876 [00:46<07:44,  3.68it/s]
# Contours processed:   9%|▉         | 168/1876 [00:46<07:45,  3.67it/s]
# Contours processed:   9%|▉         | 169/1876 [00:46<07:46,  3.66it/s]
# Contours processed:   9%|▉         | 170/1876 [00:47<07:46,  3.66it/s]
# Contours processed:   9%|▉         | 171/1876 [00:47<07:43,  3.68it/s]
# Contours processed:   9%|▉         | 172/1876 [00:47<07:40,  3.70it/s]
# Contours processed:   9%|▉         | 173/1876 [00:47<07:38,  3.72it/s]
# Contours processed:   9%|▉         | 174/1876 [00:48<07:40,  3.69it/s]
# Contours processed:   9%|▉         | 175/1876 [00:48<07:39,  3.70it/s]
# Contours processed:   9%|▉         | 176/1876 [00:48<07:38,  3.71it/s]
# Contours processed:   9%|▉         | 177/1876 [00:48<07:43,  3.66it/s]
# Contours processed:   9%|▉         | 178/1876 [00:49<07:46,  3.64it/s]
# Contours processed:  10%|▉         | 179/1876 [00:49<07:48,  3.62it/s]
# Contours processed:  10%|▉         | 180/1876 [00:49<07:51,  3.60it/s]
# Contours processed:  10%|▉         | 181/1876 [00:50<07:45,  3.64it/s]
# Contours processed:  10%|▉         | 182/1876 [00:50<07:42,  3.66it/s]
# Contours processed:  10%|▉         | 183/1876 [00:50<07:40,  3.67it/s]
# Contours processed:  10%|▉         | 184/1876 [00:50<07:39,  3.68it/s]
# Contours processed:  10%|▉         | 185/1876 [00:51<07:37,  3.69it/s]
# Contours processed:  10%|▉         | 186/1876 [00:51<07:36,  3.70it/s]
# Contours processed:  10%|▉         | 187/1876 [00:51<07:35,  3.71it/s]
# Contours processed:  10%|█         | 188/1876 [00:51<07:34,  3.71it/s]
# Contours processed:  10%|█         | 189/1876 [00:52<07:32,  3.73it/s]
# Contours processed:  10%|█         | 190/1876 [00:52<07:32,  3.73it/s]
# Contours processed:  10%|█         | 191/1876 [00:52<07:32,  3.72it/s]
# Contours processed:  10%|█         | 192/1876 [00:53<07:37,  3.68it/s]
# Contours processed:  10%|█         | 193/1876 [00:53<07:46,  3.61it/s]
# Contours processed:  10%|█         | 194/1876 [00:53<07:53,  3.55it/s]
# Contours processed:  10%|█         | 195/1876 [00:53<07:48,  3.59it/s]
# Contours processed:  10%|█         | 196/1876 [00:54<07:47,  3.59it/s]
# Contours processed:  11%|█         | 197/1876 [00:54<07:41,  3.64it/s]
# Contours processed:  11%|█         | 198/1876 [00:54<07:40,  3.64it/s]
# Contours processed:  11%|█         | 199/1876 [00:55<07:39,  3.65it/s]
# Contours processed:  11%|█         | 200/1876 [00:55<07:35,  3.68it/s]
# Contours processed:  11%|█         | 201/1876 [00:55<07:34,  3.69it/s]
# Contours processed:  11%|█         | 202/1876 [00:55<07:36,  3.67it/s]
# Contours processed:  11%|█         | 203/1876 [00:56<07:32,  3.69it/s]
# Contours processed:  11%|█         | 204/1876 [00:56<07:30,  3.71it/s]
# Contours processed:  11%|█         | 205/1876 [00:56<07:30,  3.71it/s]
# Contours processed:  11%|█         | 206/1876 [00:56<07:32,  3.69it/s]
# Contours processed:  11%|█         | 207/1876 [00:57<07:31,  3.70it/s]
# Contours processed:  11%|█         | 208/1876 [00:57<07:30,  3.70it/s]
# Contours processed:  11%|█         | 209/1876 [00:57<07:28,  3.72it/s]
# Contours processed:  11%|█         | 210/1876 [00:57<07:28,  3.72it/s]
# Contours processed:  11%|█         | 211/1876 [00:58<07:27,  3.72it/s]
# Contours processed:  11%|█▏        | 212/1876 [00:58<07:26,  3.73it/s]
# Contours processed:  11%|█▏        | 213/1876 [00:58<07:25,  3.73it/s]
# Contours processed:  11%|█▏        | 214/1876 [00:59<07:27,  3.72it/s]
# Contours processed:  11%|█▏        | 215/1876 [00:59<07:26,  3.72it/s]
# Contours processed:  12%|█▏        | 216/1876 [00:59<07:26,  3.72it/s]
# Contours processed:  12%|█▏        | 217/1876 [00:59<07:27,  3.71it/s]
# Contours processed:  12%|█▏        | 218/1876 [01:00<07:26,  3.71it/s]
# Contours processed:  12%|█▏        | 219/1876 [01:00<07:25,  3.72it/s]
# Contours processed:  12%|█▏        | 220/1876 [01:00<07:24,  3.73it/s]
# Contours processed:  12%|█▏        | 221/1876 [01:00<07:23,  3.73it/s]
# Contours processed:  12%|█▏        | 222/1876 [01:01<07:24,  3.72it/s]
# Contours processed:  12%|█▏        | 223/1876 [01:01<07:23,  3.73it/s]
# Contours processed:  12%|█▏        | 224/1876 [01:01<07:22,  3.73it/s]
# Contours processed:  12%|█▏        | 225/1876 [01:02<07:22,  3.73it/s]
# Contours processed:  12%|█▏        | 226/1876 [01:02<07:23,  3.72it/s]
# Contours processed:  12%|█▏        | 227/1876 [01:02<07:22,  3.73it/s]
# Contours processed:  12%|█▏        | 228/1876 [01:02<07:21,  3.73it/s]
# Contours processed:  12%|█▏        | 229/1876 [01:03<07:30,  3.65it/s]
# Contours processed:  12%|█▏        | 230/1876 [01:03<07:36,  3.61it/s]
# Contours processed:  12%|█▏        | 231/1876 [01:03<07:30,  3.65it/s]
# Contours processed:  12%|█▏        | 232/1876 [01:03<07:28,  3.66it/s]
# Contours processed:  12%|█▏        | 233/1876 [01:04<07:26,  3.68it/s]
# Contours processed:  12%|█▏        | 234/1876 [01:04<07:23,  3.70it/s]
# Contours processed:  13%|█▎        | 235/1876 [01:04<07:21,  3.71it/s]
# Contours processed:  13%|█▎        | 236/1876 [01:04<07:20,  3.72it/s]
# Contours processed:  13%|█▎        | 237/1876 [01:05<07:20,  3.72it/s]
# Contours processed:  13%|█▎        | 238/1876 [01:05<07:20,  3.72it/s]
# Contours processed:  13%|█▎        | 239/1876 [01:05<07:19,  3.72it/s]
# Contours processed:  13%|█▎        | 240/1876 [01:06<07:18,  3.73it/s]
# Contours processed:  13%|█▎        | 241/1876 [01:06<07:18,  3.73it/s]
# Contours processed:  13%|█▎        | 242/1876 [01:06<07:17,  3.73it/s]
# Contours processed:  13%|█▎        | 243/1876 [01:06<07:17,  3.74it/s]
# Contours processed:  13%|█▎        | 244/1876 [01:07<07:17,  3.73it/s]
# Contours processed:  13%|█▎        | 245/1876 [01:07<07:18,  3.72it/s]
# Contours processed:  13%|█▎        | 246/1876 [01:07<07:17,  3.73it/s]
# Contours processed:  13%|█▎        | 247/1876 [01:07<07:17,  3.73it/s]
# Contours processed:  13%|█▎        | 248/1876 [01:08<07:16,  3.73it/s]
# Contours processed:  13%|█▎        | 249/1876 [01:08<07:16,  3.73it/s]
# Contours processed:  13%|█▎        | 250/1876 [01:08<07:15,  3.74it/s]
# Contours processed:  13%|█▎        | 251/1876 [01:09<07:18,  3.70it/s]
# Contours processed:  13%|█▎        | 252/1876 [01:09<07:25,  3.65it/s]
# Contours processed:  13%|█▎        | 253/1876 [01:09<07:34,  3.57it/s]
# Contours processed:  14%|█▎        | 254/1876 [01:09<07:33,  3.58it/s]
# Contours processed:  14%|█▎        | 255/1876 [01:10<07:28,  3.61it/s]
# Contours processed:  14%|█▎        | 256/1876 [01:10<07:25,  3.64it/s]
# Contours processed:  14%|█▎        | 257/1876 [01:10<07:20,  3.68it/s]
# Contours processed:  14%|█▍        | 258/1876 [01:10<07:18,  3.69it/s]
# Contours processed:  14%|█▍        | 259/1876 [01:11<07:16,  3.71it/s]
# Contours processed:  14%|█▍        | 260/1876 [01:11<07:15,  3.71it/s]
# Contours processed:  14%|█▍        | 261/1876 [01:11<07:14,  3.71it/s]
# Contours processed:  14%|█▍        | 262/1876 [01:12<07:15,  3.71it/s]
# Contours processed:  14%|█▍        | 263/1876 [01:12<07:14,  3.71it/s]
# Contours processed:  14%|█▍        | 264/1876 [01:12<07:14,  3.71it/s]
# Contours processed:  14%|█▍        | 265/1876 [01:12<07:14,  3.71it/s]
# Contours processed:  14%|█▍        | 266/1876 [01:13<07:13,  3.72it/s]
# Contours processed:  14%|█▍        | 267/1876 [01:13<07:11,  3.73it/s]
# Contours processed:  14%|█▍        | 268/1876 [01:13<07:13,  3.71it/s]
# Contours processed:  14%|█▍        | 269/1876 [01:13<07:14,  3.70it/s]
# Contours processed:  14%|█▍        | 270/1876 [01:14<07:13,  3.70it/s]
# Contours processed:  14%|█▍        | 271/1876 [01:14<07:13,  3.70it/s]
# Contours processed:  14%|█▍        | 272/1876 [01:14<07:12,  3.71it/s]
# Contours processed:  15%|█▍        | 273/1876 [01:14<07:13,  3.70it/s]
# Contours processed:  15%|█▍        | 274/1876 [01:15<07:11,  3.71it/s]
# Contours processed:  15%|█▍        | 275/1876 [01:15<07:09,  3.73it/s]
# Contours processed:  15%|█▍        | 276/1876 [01:15<07:11,  3.71it/s]
# Contours processed:  15%|█▍        | 277/1876 [01:16<07:11,  3.70it/s]
# Contours processed:  15%|█▍        | 278/1876 [01:16<07:10,  3.71it/s]
# Contours processed:  15%|█▍        | 279/1876 [01:16<07:10,  3.71it/s]
# Contours processed:  15%|█▍        | 280/1876 [01:16<07:09,  3.72it/s]
# Contours processed:  15%|█▍        | 281/1876 [01:17<07:09,  3.71it/s]
# Contours processed:  15%|█▌        | 282/1876 [01:17<07:08,  3.72it/s]
# Contours processed:  15%|█▌        | 283/1876 [01:17<07:07,  3.73it/s]
# Contours processed:  15%|█▌        | 284/1876 [01:17<07:07,  3.72it/s]
# Contours processed:  15%|█▌        | 285/1876 [01:18<07:07,  3.72it/s]
# Contours processed:  15%|█▌        | 286/1876 [01:18<07:07,  3.72it/s]
# Contours processed:  15%|█▌        | 287/1876 [01:18<07:06,  3.72it/s]
# Contours processed:  15%|█▌        | 288/1876 [01:19<07:07,  3.71it/s]
# Contours processed:  15%|█▌        | 289/1876 [01:19<07:07,  3.71it/s]
# Contours processed:  15%|█▌        | 290/1876 [01:19<07:05,  3.73it/s]
# Contours processed:  16%|█▌        | 291/1876 [01:19<07:05,  3.72it/s]
# Contours processed:  16%|█▌        | 292/1876 [01:20<07:04,  3.73it/s]
# Contours processed:  16%|█▌        | 293/1876 [01:20<07:05,  3.72it/s]
# Contours processed:  16%|█▌        | 294/1876 [01:20<07:04,  3.73it/s]
# Contours processed:  16%|█▌        | 295/1876 [01:20<07:04,  3.72it/s]
# Contours processed:  16%|█▌        | 296/1876 [01:21<07:04,  3.72it/s]
# Contours processed:  16%|█▌        | 297/1876 [01:21<07:05,  3.71it/s]
# Contours processed:  16%|█▌        | 298/1876 [01:21<07:04,  3.72it/s]
# Contours processed:  16%|█▌        | 299/1876 [01:21<07:04,  3.71it/s]
# Contours processed:  16%|█▌        | 300/1876 [01:22<07:03,  3.72it/s]
# Contours processed:  16%|█▌        | 301/1876 [01:22<07:03,  3.72it/s]
# Contours processed:  16%|█▌        | 302/1876 [01:22<07:04,  3.70it/s]
# Contours processed:  16%|█▌        | 303/1876 [01:23<07:04,  3.71it/s]
# Contours processed:  16%|█▌        | 304/1876 [01:23<07:03,  3.71it/s]
# Contours processed:  16%|█▋        | 305/1876 [01:23<07:02,  3.72it/s]
# Contours processed:  16%|█▋        | 306/1876 [01:23<07:01,  3.72it/s]
# Contours processed:  16%|█▋        | 307/1876 [01:24<07:00,  3.73it/s]
# Contours processed:  16%|█▋        | 308/1876 [01:24<07:00,  3.73it/s]
# Contours processed:  16%|█▋        | 309/1876 [01:24<07:00,  3.73it/s]
# Contours processed:  17%|█▋        | 310/1876 [01:24<07:01,  3.72it/s]
# Contours processed:  17%|█▋        | 311/1876 [01:25<07:11,  3.63it/s]
# Contours processed:  17%|█▋        | 312/1876 [01:25<07:21,  3.54it/s]
# Contours processed:  17%|█▋        | 313/1876 [01:25<07:23,  3.52it/s]
# Contours processed:  17%|█▋        | 314/1876 [01:26<07:19,  3.55it/s]
# Contours processed:  17%|█▋        | 315/1876 [01:26<07:13,  3.60it/s]
# Contours processed:  17%|█▋        | 316/1876 [01:26<07:08,  3.64it/s]
# Contours processed:  17%|█▋        | 317/1876 [01:26<07:07,  3.65it/s]
# Contours processed:  17%|█▋        | 318/1876 [01:27<07:06,  3.65it/s]
# Contours processed:  17%|█▋        | 319/1876 [01:27<07:04,  3.67it/s]
# Contours processed:  17%|█▋        | 320/1876 [01:27<07:02,  3.68it/s]
# Contours processed:  17%|█▋        | 321/1876 [01:27<07:02,  3.68it/s]
# Contours processed:  17%|█▋        | 322/1876 [01:28<06:59,  3.70it/s]
# Contours processed:  17%|█▋        | 323/1876 [01:28<06:58,  3.71it/s]
# Contours processed:  17%|█▋        | 324/1876 [01:28<06:58,  3.71it/s]
# Contours processed:  17%|█▋        | 325/1876 [01:29<06:59,  3.70it/s]
# Contours processed:  17%|█▋        | 326/1876 [01:29<07:00,  3.69it/s]
# Contours processed:  17%|█▋        | 327/1876 [01:29<07:00,  3.69it/s]
# Contours processed:  17%|█▋        | 328/1876 [01:29<07:00,  3.68it/s]
# Contours processed:  18%|█▊        | 329/1876 [01:30<06:58,  3.70it/s]
# Contours processed:  18%|█▊        | 330/1876 [01:30<07:00,  3.68it/s]
# Contours processed:  18%|█▊        | 331/1876 [01:30<06:57,  3.70it/s]
# Contours processed:  18%|█▊        | 332/1876 [01:30<06:56,  3.71it/s]
# Contours processed:  18%|█▊        | 333/1876 [01:31<06:56,  3.71it/s]
# Contours processed:  18%|█▊        | 334/1876 [01:31<06:54,  3.72it/s]
# Contours processed:  18%|█▊        | 335/1876 [01:31<06:53,  3.72it/s]
# Contours processed:  18%|█▊        | 336/1876 [01:32<06:52,  3.73it/s]
# Contours processed:  18%|█▊        | 337/1876 [01:32<06:52,  3.73it/s]
# Contours processed:  18%|█▊        | 338/1876 [01:32<06:52,  3.73it/s]
# Contours processed:  18%|█▊        | 339/1876 [01:32<06:51,  3.73it/s]
# Contours processed:  18%|█▊        | 340/1876 [01:33<06:51,  3.73it/s]
# Contours processed:  18%|█▊        | 341/1876 [01:33<06:55,  3.69it/s]
# Contours processed:  18%|█▊        | 342/1876 [01:33<06:54,  3.70it/s]
# Contours processed:  18%|█▊        | 343/1876 [01:33<06:54,  3.70it/s]
# Contours processed:  18%|█▊        | 344/1876 [01:34<06:53,  3.70it/s]
# Contours processed:  18%|█▊        | 345/1876 [01:34<06:53,  3.70it/s]
# Contours processed:  18%|█▊        | 346/1876 [01:34<06:52,  3.71it/s]
# Contours processed:  18%|█▊        | 347/1876 [01:34<06:52,  3.71it/s]
# Contours processed:  19%|█▊        | 348/1876 [01:35<06:50,  3.72it/s]
# Contours processed:  19%|█▊        | 349/1876 [01:35<06:49,  3.73it/s]
# Contours processed:  19%|█▊        | 350/1876 [01:35<06:48,  3.73it/s]
# Contours processed:  19%|█▊        | 351/1876 [01:36<06:49,  3.73it/s]
# Contours processed:  19%|█▉        | 352/1876 [01:36<06:49,  3.72it/s]
# Contours processed:  19%|█▉        | 353/1876 [01:36<06:47,  3.74it/s]
# Contours processed:  19%|█▉        | 354/1876 [01:36<06:48,  3.73it/s]
# Contours processed:  19%|█▉        | 355/1876 [01:37<06:52,  3.69it/s]
# Contours processed:  19%|█▉        | 356/1876 [01:37<06:51,  3.70it/s]
# Contours processed:  19%|█▉        | 357/1876 [01:37<06:49,  3.71it/s]
# Contours processed:  19%|█▉        | 358/1876 [01:37<06:49,  3.70it/s]
# Contours processed:  19%|█▉        | 359/1876 [01:38<06:48,  3.71it/s]
# Contours processed:  19%|█▉        | 360/1876 [01:38<06:48,  3.72it/s]
# Contours processed:  19%|█▉        | 361/1876 [01:38<06:49,  3.70it/s]
# Contours processed:  19%|█▉        | 362/1876 [01:39<06:52,  3.67it/s]
# Contours processed:  19%|█▉        | 363/1876 [01:39<06:56,  3.63it/s]
# Contours processed:  19%|█▉        | 364/1876 [01:39<07:00,  3.59it/s]
# Contours processed:  19%|█▉        | 365/1876 [01:39<07:03,  3.57it/s]
# Contours processed:  20%|█▉        | 366/1876 [01:40<07:06,  3.54it/s]
# Contours processed:  20%|█▉        | 367/1876 [01:40<07:10,  3.51it/s]
# Contours processed:  20%|█▉        | 368/1876 [01:40<07:13,  3.48it/s]
# Contours processed:  20%|█▉        | 369/1876 [01:41<07:22,  3.40it/s]
# Contours processed:  20%|█▉        | 370/1876 [01:41<07:24,  3.39it/s]
# Contours processed:  20%|█▉        | 371/1876 [01:41<07:26,  3.37it/s]
# Contours processed:  20%|█▉        | 372/1876 [01:41<07:27,  3.36it/s]
# Contours processed:  20%|█▉        | 373/1876 [01:42<07:25,  3.37it/s]
# Contours processed:  20%|█▉        | 374/1876 [01:42<07:25,  3.37it/s]
# Contours processed:  20%|█▉        | 375/1876 [01:42<07:33,  3.31it/s]
# Contours processed:  20%|██        | 376/1876 [01:43<07:31,  3.32it/s]
# Contours processed:  20%|██        | 377/1876 [01:43<07:20,  3.40it/s]
# Contours processed:  20%|██        | 378/1876 [01:43<07:13,  3.45it/s]
# Contours processed:  20%|██        | 379/1876 [01:44<07:08,  3.49it/s]
# Contours processed:  20%|██        | 380/1876 [01:44<07:01,  3.55it/s]
# Contours processed:  20%|██        | 381/1876 [01:44<07:32,  3.31it/s]
# Contours processed:  20%|██        | 382/1876 [01:44<07:34,  3.29it/s]
# Contours processed:  20%|██        | 383/1876 [01:45<07:19,  3.40it/s]
# Contours processed:  20%|██        | 384/1876 [01:45<07:18,  3.40it/s]
# Contours processed:  21%|██        | 385/1876 [01:45<07:07,  3.49it/s]
# Contours processed:  21%|██        | 386/1876 [01:46<07:11,  3.45it/s]
# Contours processed:  21%|██        | 387/1876 [01:46<07:06,  3.49it/s]
# Contours processed:  21%|██        | 388/1876 [01:46<07:05,  3.50it/s]
# Contours processed:  21%|██        | 389/1876 [01:46<07:01,  3.53it/s]
# Contours processed:  21%|██        | 390/1876 [01:47<06:59,  3.54it/s]
# Contours processed:  21%|██        | 391/1876 [01:47<07:03,  3.51it/s]
# Contours processed:  21%|██        | 392/1876 [01:47<07:01,  3.52it/s]
# Contours processed:  21%|██        | 393/1876 [01:48<07:07,  3.47it/s]
# Contours processed:  21%|██        | 394/1876 [01:48<07:08,  3.46it/s]
# Contours processed:  21%|██        | 395/1876 [01:48<07:01,  3.51it/s]
# Contours processed:  21%|██        | 396/1876 [01:48<06:57,  3.54it/s]
# Contours processed:  21%|██        | 397/1876 [01:49<06:51,  3.59it/s]
# Contours processed:  21%|██        | 398/1876 [01:49<06:48,  3.62it/s]
# Contours processed:  21%|██▏       | 399/1876 [01:49<06:49,  3.61it/s]
# Contours processed:  21%|██▏       | 400/1876 [01:49<06:46,  3.64it/s]
# Contours processed:  21%|██▏       | 401/1876 [01:50<06:44,  3.65it/s]
# Contours processed:  21%|██▏       | 402/1876 [01:50<06:43,  3.65it/s]
# Contours processed:  21%|██▏       | 403/1876 [01:50<06:42,  3.66it/s]
# Contours processed:  22%|██▏       | 404/1876 [01:51<06:42,  3.66it/s]
# Contours processed:  22%|██▏       | 405/1876 [01:51<06:41,  3.67it/s]
# Contours processed:  22%|██▏       | 406/1876 [01:51<06:39,  3.68it/s]
# Contours processed:  22%|██▏       | 407/1876 [01:51<06:40,  3.67it/s]
# Contours processed:  22%|██▏       | 408/1876 [01:52<06:40,  3.66it/s]
# Contours processed:  22%|██▏       | 409/1876 [01:52<06:39,  3.67it/s]
# Contours processed:  22%|██▏       | 410/1876 [01:52<06:40,  3.66it/s]
# Contours processed:  22%|██▏       | 411/1876 [01:52<06:39,  3.67it/s]
# Contours processed:  22%|██▏       | 412/1876 [01:53<06:37,  3.68it/s]
# Contours processed:  22%|██▏       | 413/1876 [01:53<06:37,  3.68it/s]
# Contours processed:  22%|██▏       | 414/1876 [01:53<06:37,  3.68it/s]
# Contours processed:  22%|██▏       | 415/1876 [01:54<06:37,  3.68it/s]
# Contours processed:  22%|██▏       | 416/1876 [01:54<06:36,  3.68it/s]
# Contours processed:  22%|██▏       | 417/1876 [01:54<06:37,  3.67it/s]
# Contours processed:  22%|██▏       | 418/1876 [01:54<06:44,  3.60it/s]
# Contours processed:  22%|██▏       | 419/1876 [01:55<06:43,  3.61it/s]
# Contours processed:  22%|██▏       | 420/1876 [01:55<06:40,  3.64it/s]
# Contours processed:  22%|██▏       | 421/1876 [01:55<06:38,  3.65it/s]
# Contours processed:  22%|██▏       | 422/1876 [01:56<06:37,  3.66it/s]
# Contours processed:  23%|██▎       | 423/1876 [01:56<06:36,  3.66it/s]
# Contours processed:  23%|██▎       | 424/1876 [01:56<06:38,  3.65it/s]
# Contours processed:  23%|██▎       | 425/1876 [01:56<06:43,  3.60it/s]
# Contours processed:  23%|██▎       | 426/1876 [01:57<06:49,  3.54it/s]
# Contours processed:  23%|██▎       | 427/1876 [01:57<06:56,  3.48it/s]
# Contours processed:  23%|██▎       | 428/1876 [01:57<06:57,  3.46it/s]
# Contours processed:  23%|██▎       | 429/1876 [01:58<06:51,  3.52it/s]
# Contours processed:  23%|██▎       | 430/1876 [01:58<06:47,  3.55it/s]
# Contours processed:  23%|██▎       | 431/1876 [01:58<06:45,  3.56it/s]
# Contours processed:  23%|██▎       | 432/1876 [01:58<06:41,  3.60it/s]
# Contours processed:  23%|██▎       | 433/1876 [01:59<06:38,  3.62it/s]
# Contours processed:  23%|██▎       | 434/1876 [01:59<06:40,  3.60it/s]
# Contours processed:  23%|██▎       | 435/1876 [01:59<06:40,  3.60it/s]
# Contours processed:  23%|██▎       | 436/1876 [01:59<06:36,  3.63it/s]
# Contours processed:  23%|██▎       | 437/1876 [02:00<06:51,  3.49it/s]
# Contours processed:  23%|██▎       | 438/1876 [02:00<06:45,  3.55it/s]
# Contours processed:  23%|██▎       | 439/1876 [02:00<06:39,  3.59it/s]
# Contours processed:  23%|██▎       | 440/1876 [02:01<06:36,  3.62it/s]
# Contours processed:  24%|██▎       | 441/1876 [02:01<06:33,  3.65it/s]
# Contours processed:  24%|██▎       | 442/1876 [02:01<06:31,  3.67it/s]
# Contours processed:  24%|██▎       | 443/1876 [02:01<06:30,  3.67it/s]
# Contours processed:  24%|██▎       | 444/1876 [02:02<06:28,  3.69it/s]
# Contours processed:  24%|██▎       | 445/1876 [02:02<06:26,  3.70it/s]
# Contours processed:  24%|██▍       | 446/1876 [02:02<06:27,  3.69it/s]
# Contours processed:  24%|██▍       | 447/1876 [02:02<06:26,  3.69it/s]
# Contours processed:  24%|██▍       | 448/1876 [02:03<06:24,  3.71it/s]
# Contours processed:  24%|██▍       | 449/1876 [02:03<06:34,  3.61it/s]
# Contours processed:  24%|██▍       | 450/1876 [02:03<06:32,  3.63it/s]
# Contours processed:  24%|██▍       | 451/1876 [02:04<06:29,  3.66it/s]
# Contours processed:  24%|██▍       | 452/1876 [02:04<06:26,  3.69it/s]
# Contours processed:  24%|██▍       | 453/1876 [02:04<06:24,  3.70it/s]
# Contours processed:  24%|██▍       | 454/1876 [02:04<06:24,  3.70it/s]
# Contours processed:  24%|██▍       | 455/1876 [02:05<06:22,  3.72it/s]
# Contours processed:  24%|██▍       | 456/1876 [02:05<06:22,  3.72it/s]
# Contours processed:  24%|██▍       | 457/1876 [02:05<06:22,  3.71it/s]
# Contours processed:  24%|██▍       | 458/1876 [02:05<06:22,  3.71it/s]
# Contours processed:  24%|██▍       | 459/1876 [02:06<06:21,  3.72it/s]
# Contours processed:  25%|██▍       | 460/1876 [02:06<06:19,  3.73it/s]
# Contours processed:  25%|██▍       | 461/1876 [02:06<06:20,  3.72it/s]
# Contours processed:  25%|██▍       | 462/1876 [02:06<06:20,  3.72it/s]
# Contours processed:  25%|██▍       | 463/1876 [02:07<06:19,  3.73it/s]
# Contours processed:  25%|██▍       | 464/1876 [02:07<06:19,  3.72it/s]
# Contours processed:  25%|██▍       | 465/1876 [02:07<06:23,  3.68it/s]
# Contours processed:  25%|██▍       | 466/1876 [02:08<06:22,  3.68it/s]
# Contours processed:  25%|██▍       | 467/1876 [02:08<06:21,  3.69it/s]
# Contours processed:  25%|██▍       | 468/1876 [02:08<06:19,  3.71it/s]
# Contours processed:  25%|██▌       | 469/1876 [02:08<06:19,  3.71it/s]
# Contours processed:  25%|██▌       | 470/1876 [02:09<06:17,  3.72it/s]
# Contours processed:  25%|██▌       | 471/1876 [02:09<06:17,  3.72it/s]
# Contours processed:  25%|██▌       | 472/1876 [02:09<06:18,  3.71it/s]
# Contours processed:  25%|██▌       | 473/1876 [02:09<06:18,  3.71it/s]
# Contours processed:  25%|██▌       | 474/1876 [02:10<06:18,  3.71it/s]
# Contours processed:  25%|██▌       | 475/1876 [02:10<06:16,  3.72it/s]
# Contours processed:  25%|██▌       | 476/1876 [02:10<06:15,  3.72it/s]
# Contours processed:  25%|██▌       | 477/1876 [02:11<06:15,  3.72it/s]
# Contours processed:  25%|██▌       | 478/1876 [02:11<06:15,  3.72it/s]
# Contours processed:  26%|██▌       | 479/1876 [02:11<06:15,  3.72it/s]
# Contours processed:  26%|██▌       | 480/1876 [02:11<06:15,  3.72it/s]
# Contours processed:  26%|██▌       | 481/1876 [02:12<06:16,  3.70it/s]
# Contours processed:  26%|██▌       | 482/1876 [02:12<06:15,  3.71it/s]
# Contours processed:  26%|██▌       | 483/1876 [02:12<06:14,  3.72it/s]
# Contours processed:  26%|██▌       | 484/1876 [02:12<06:13,  3.73it/s]
# Contours processed:  26%|██▌       | 485/1876 [02:13<06:22,  3.63it/s]
# Contours processed:  26%|██▌       | 486/1876 [02:13<06:30,  3.56it/s]
# Contours processed:  26%|██▌       | 487/1876 [02:13<06:30,  3.56it/s]
# Contours processed:  26%|██▌       | 488/1876 [02:14<06:26,  3.60it/s]
# Contours processed:  26%|██▌       | 489/1876 [02:14<06:22,  3.62it/s]
# Contours processed:  26%|██▌       | 490/1876 [02:14<06:19,  3.65it/s]
# Contours processed:  26%|██▌       | 491/1876 [02:14<06:17,  3.66it/s]
# Contours processed:  26%|██▌       | 492/1876 [02:15<06:14,  3.70it/s]
# Contours processed:  26%|██▋       | 493/1876 [02:15<06:12,  3.71it/s]
# Contours processed:  26%|██▋       | 494/1876 [02:15<06:11,  3.72it/s]
# Contours processed:  26%|██▋       | 495/1876 [02:15<06:11,  3.72it/s]
# Contours processed:  26%|██▋       | 496/1876 [02:16<06:10,  3.72it/s]
# Contours processed:  26%|██▋       | 497/1876 [02:16<06:11,  3.71it/s]
# Contours processed:  27%|██▋       | 498/1876 [02:16<06:11,  3.70it/s]
# Contours processed:  27%|██▋       | 499/1876 [02:17<06:11,  3.71it/s]
# Contours processed:  27%|██▋       | 500/1876 [02:17<06:09,  3.72it/s]
# Contours processed:  27%|██▋       | 501/1876 [02:17<06:09,  3.72it/s]
# Contours processed:  27%|██▋       | 502/1876 [02:17<06:10,  3.71it/s]
# Contours processed:  27%|██▋       | 503/1876 [02:18<06:10,  3.70it/s]
# Contours processed:  27%|██▋       | 504/1876 [02:18<06:11,  3.70it/s]
# Contours processed:  27%|██▋       | 505/1876 [02:18<06:10,  3.70it/s]
# Contours processed:  27%|██▋       | 506/1876 [02:18<06:09,  3.71it/s]
# Contours processed:  27%|██▋       | 507/1876 [02:19<06:07,  3.73it/s]
# Contours processed:  27%|██▋       | 508/1876 [02:19<06:06,  3.73it/s]
# Contours processed:  27%|██▋       | 509/1876 [02:19<06:06,  3.73it/s]
# Contours processed:  27%|██▋       | 510/1876 [02:19<06:06,  3.73it/s]
# Contours processed:  27%|██▋       | 511/1876 [02:20<06:06,  3.73it/s]
# Contours processed:  27%|██▋       | 512/1876 [02:20<06:06,  3.72it/s]
# Contours processed:  27%|██▋       | 513/1876 [02:20<06:06,  3.72it/s]
# Contours processed:  27%|██▋       | 514/1876 [02:21<06:05,  3.73it/s]
# Contours processed:  27%|██▋       | 515/1876 [02:21<06:05,  3.72it/s]
# Contours processed:  28%|██▊       | 516/1876 [02:21<06:04,  3.73it/s]
# Contours processed:  28%|██▊       | 517/1876 [02:21<06:06,  3.71it/s]
# Contours processed:  28%|██▊       | 518/1876 [02:22<06:05,  3.72it/s]
# Contours processed:  28%|██▊       | 519/1876 [02:22<06:04,  3.73it/s]
# Contours processed:  28%|██▊       | 520/1876 [02:22<06:03,  3.73it/s]
# Contours processed:  28%|██▊       | 521/1876 [02:22<06:04,  3.71it/s]
# Contours processed:  28%|██▊       | 522/1876 [02:23<06:03,  3.72it/s]
# Contours processed:  28%|██▊       | 523/1876 [02:23<06:03,  3.73it/s]
# Contours processed:  28%|██▊       | 524/1876 [02:23<06:03,  3.72it/s]
# Contours processed:  28%|██▊       | 525/1876 [02:24<06:09,  3.66it/s]
# Contours processed:  28%|██▊       | 526/1876 [02:24<06:13,  3.61it/s]
# Contours processed:  28%|██▊       | 527/1876 [02:24<06:11,  3.63it/s]
# Contours processed:  28%|██▊       | 528/1876 [02:24<06:09,  3.65it/s]
# Contours processed:  28%|██▊       | 529/1876 [02:25<06:07,  3.67it/s]
# Contours processed:  28%|██▊       | 530/1876 [02:25<06:05,  3.69it/s]
# Contours processed:  28%|██▊       | 531/1876 [02:25<06:03,  3.70it/s]
# Contours processed:  28%|██▊       | 532/1876 [02:25<06:01,  3.71it/s]
# Contours processed:  28%|██▊       | 533/1876 [02:26<06:01,  3.72it/s]
# Contours processed:  28%|██▊       | 534/1876 [02:26<06:04,  3.69it/s]
# Contours processed:  29%|██▊       | 535/1876 [02:26<06:04,  3.68it/s]
# Contours processed:  29%|██▊       | 536/1876 [02:27<06:05,  3.67it/s]
# Contours processed:  29%|██▊       | 537/1876 [02:27<06:03,  3.68it/s]
# Contours processed:  29%|██▊       | 538/1876 [02:27<06:04,  3.67it/s]
# Contours processed:  29%|██▊       | 539/1876 [02:27<06:02,  3.69it/s]
# Contours processed:  29%|██▉       | 540/1876 [02:28<06:01,  3.70it/s]
# Contours processed:  29%|██▉       | 541/1876 [02:28<06:00,  3.71it/s]
# Contours processed:  29%|██▉       | 542/1876 [02:28<06:01,  3.69it/s]
# Contours processed:  29%|██▉       | 543/1876 [02:28<06:01,  3.69it/s]
# Contours processed:  29%|██▉       | 544/1876 [02:29<06:07,  3.62it/s]
# Contours processed:  29%|██▉       | 545/1876 [02:29<06:13,  3.56it/s]
# Contours processed:  29%|██▉       | 546/1876 [02:29<06:13,  3.56it/s]
# Contours processed:  29%|██▉       | 547/1876 [02:30<06:12,  3.57it/s]
# Contours processed:  29%|██▉       | 548/1876 [02:30<06:08,  3.60it/s]
# Contours processed:  29%|██▉       | 549/1876 [02:30<06:04,  3.64it/s]
# Contours processed:  29%|██▉       | 550/1876 [02:30<06:01,  3.67it/s]
# Contours processed:  29%|██▉       | 551/1876 [02:31<06:00,  3.67it/s]
# Contours processed:  29%|██▉       | 552/1876 [02:31<05:58,  3.69it/s]
# Contours processed:  29%|██▉       | 553/1876 [02:31<05:57,  3.70it/s]
# Contours processed:  30%|██▉       | 554/1876 [02:31<05:56,  3.71it/s]
# Contours processed:  30%|██▉       | 555/1876 [02:32<05:56,  3.70it/s]
# Contours processed:  30%|██▉       | 556/1876 [02:32<05:55,  3.71it/s]
# Contours processed:  30%|██▉       | 557/1876 [02:32<05:55,  3.71it/s]
# Contours processed:  30%|██▉       | 558/1876 [02:33<05:54,  3.71it/s]
# Contours processed:  30%|██▉       | 559/1876 [02:33<05:54,  3.72it/s]
# Contours processed:  30%|██▉       | 560/1876 [02:33<05:53,  3.72it/s]
# Contours processed:  30%|██▉       | 561/1876 [02:33<05:55,  3.70it/s]
# Contours processed:  30%|██▉       | 562/1876 [02:34<05:53,  3.72it/s]
# Contours processed:  30%|███       | 563/1876 [02:34<05:53,  3.72it/s]
# Contours processed:  30%|███       | 564/1876 [02:34<05:52,  3.72it/s]
# Contours processed:  30%|███       | 565/1876 [02:34<05:55,  3.68it/s]
# Contours processed:  30%|███       | 566/1876 [02:35<06:07,  3.56it/s]
# Contours processed:  30%|███       | 567/1876 [02:35<06:15,  3.49it/s]
# Contours processed:  30%|███       | 568/1876 [02:35<06:22,  3.42it/s]
# Contours processed:  30%|███       | 569/1876 [02:36<06:24,  3.40it/s]
# Contours processed:  30%|███       | 570/1876 [02:36<06:26,  3.38it/s]
# Contours processed:  30%|███       | 571/1876 [02:36<06:30,  3.34it/s]
# Contours processed:  30%|███       | 572/1876 [02:37<06:31,  3.33it/s]
# Contours processed:  31%|███       | 573/1876 [02:37<06:31,  3.33it/s]
# Contours processed:  31%|███       | 574/1876 [02:37<06:34,  3.30it/s]
# Contours processed:  31%|███       | 575/1876 [02:37<06:20,  3.42it/s]
# Contours processed:  31%|███       | 576/1876 [02:38<06:10,  3.51it/s]
# Contours processed:  31%|███       | 577/1876 [02:38<06:02,  3.59it/s]
# Contours processed:  31%|███       | 578/1876 [02:38<05:58,  3.62it/s]
# Contours processed:  31%|███       | 579/1876 [02:38<05:55,  3.65it/s]
# Contours processed:  31%|███       | 580/1876 [02:39<05:53,  3.66it/s]
# Contours processed:  31%|███       | 581/1876 [02:39<05:51,  3.68it/s]
# Contours processed:  31%|███       | 582/1876 [02:39<05:50,  3.69it/s]
# Contours processed:  31%|███       | 583/1876 [02:40<05:48,  3.71it/s]
# Contours processed:  31%|███       | 584/1876 [02:40<05:46,  3.72it/s]
# Contours processed:  31%|███       | 585/1876 [02:40<05:44,  3.74it/s]
# Contours processed:  31%|███       | 586/1876 [02:40<05:45,  3.74it/s]
# Contours processed:  31%|███▏      | 587/1876 [02:41<05:44,  3.74it/s]
# Contours processed:  31%|███▏      | 588/1876 [02:41<05:51,  3.67it/s]
# Contours processed:  31%|███▏      | 589/1876 [02:41<05:49,  3.68it/s]
# Contours processed:  31%|███▏      | 590/1876 [02:41<05:48,  3.69it/s]
# Contours processed:  32%|███▏      | 591/1876 [02:42<05:49,  3.68it/s]
# Contours processed:  32%|███▏      | 592/1876 [02:42<05:48,  3.68it/s]
# Contours processed:  32%|███▏      | 593/1876 [02:42<05:47,  3.69it/s]
# Contours processed:  32%|███▏      | 594/1876 [02:43<05:47,  3.69it/s]
# Contours processed:  32%|███▏      | 595/1876 [02:43<05:47,  3.68it/s]
# Contours processed:  32%|███▏      | 596/1876 [02:43<05:48,  3.68it/s]
# Contours processed:  32%|███▏      | 597/1876 [02:43<05:48,  3.67it/s]
# Contours processed:  32%|███▏      | 598/1876 [02:44<05:45,  3.69it/s]
# Contours processed:  32%|███▏      | 599/1876 [02:44<05:44,  3.70it/s]
# Contours processed:  32%|███▏      | 600/1876 [02:44<05:43,  3.72it/s]
# Contours processed:  32%|███▏      | 601/1876 [02:44<05:42,  3.73it/s]
# Contours processed:  32%|███▏      | 602/1876 [02:45<05:49,  3.64it/s]
# Contours processed:  32%|███▏      | 603/1876 [02:45<05:54,  3.59it/s]
# Contours processed:  32%|███▏      | 604/1876 [02:45<05:58,  3.55it/s]
# Contours processed:  32%|███▏      | 605/1876 [02:46<05:53,  3.59it/s]
# Contours processed:  32%|███▏      | 606/1876 [02:46<05:49,  3.64it/s]
# Contours processed:  32%|███▏      | 607/1876 [02:46<05:46,  3.66it/s]
# Contours processed:  32%|███▏      | 608/1876 [02:46<05:44,  3.68it/s]
# Contours processed:  32%|███▏      | 609/1876 [02:47<05:43,  3.69it/s]
# Contours processed:  33%|███▎      | 610/1876 [02:47<05:42,  3.69it/s]
# Contours processed:  33%|███▎      | 611/1876 [02:47<05:42,  3.70it/s]
# Contours processed:  33%|███▎      | 612/1876 [02:47<05:41,  3.70it/s]
# Contours processed:  33%|███▎      | 613/1876 [02:48<05:57,  3.53it/s]
# Contours processed:  33%|███▎      | 614/1876 [02:48<05:57,  3.53it/s]
# Contours processed:  33%|███▎      | 615/1876 [02:48<05:52,  3.58it/s]
# Contours processed:  33%|███▎      | 616/1876 [02:49<05:47,  3.63it/s]
# Contours processed:  33%|███▎      | 617/1876 [02:49<05:44,  3.66it/s]
# Contours processed:  33%|███▎      | 618/1876 [02:49<05:41,  3.68it/s]
# Contours processed:  33%|███▎      | 619/1876 [02:49<05:41,  3.68it/s]
# Contours processed:  33%|███▎      | 620/1876 [02:50<05:40,  3.69it/s]
# Contours processed:  33%|███▎      | 621/1876 [02:50<05:39,  3.70it/s]
# Contours processed:  33%|███▎      | 622/1876 [02:50<05:38,  3.71it/s]
# Contours processed:  33%|███▎      | 623/1876 [02:50<05:36,  3.72it/s]
# Contours processed:  33%|███▎      | 624/1876 [02:51<05:35,  3.73it/s]
# Contours processed:  33%|███▎      | 625/1876 [02:51<05:35,  3.73it/s]
# Contours processed:  33%|███▎      | 626/1876 [02:51<05:36,  3.72it/s]
# Contours processed:  33%|███▎      | 627/1876 [02:52<05:39,  3.68it/s]
# Contours processed:  33%|███▎      | 628/1876 [02:52<05:37,  3.69it/s]
# Contours processed:  34%|███▎      | 629/1876 [02:52<05:37,  3.70it/s]
# Contours processed:  34%|███▎      | 630/1876 [02:52<05:36,  3.70it/s]
# Contours processed:  34%|███▎      | 631/1876 [02:53<05:34,  3.72it/s]
# Contours processed:  34%|███▎      | 632/1876 [02:53<05:33,  3.73it/s]
# Contours processed:  34%|███▎      | 633/1876 [02:53<05:35,  3.71it/s]
# Contours processed:  34%|███▍      | 634/1876 [02:53<05:43,  3.62it/s]
# Contours processed:  34%|███▍      | 635/1876 [02:54<05:40,  3.65it/s]
# Contours processed:  34%|███▍      | 636/1876 [02:54<05:38,  3.67it/s]
# Contours processed:  34%|███▍      | 637/1876 [02:54<05:38,  3.66it/s]
# Contours processed:  34%|███▍      | 638/1876 [02:55<05:36,  3.68it/s]
# Contours processed:  34%|███▍      | 639/1876 [02:55<05:34,  3.70it/s]
# Contours processed:  34%|███▍      | 640/1876 [02:55<05:33,  3.70it/s]
# Contours processed:  34%|███▍      | 641/1876 [02:55<05:33,  3.71it/s]
# Contours processed:  34%|███▍      | 642/1876 [02:56<05:32,  3.71it/s]
# Contours processed:  34%|███▍      | 643/1876 [02:56<05:32,  3.71it/s]
# Contours processed:  34%|███▍      | 644/1876 [02:56<05:31,  3.72it/s]
# Contours processed:  34%|███▍      | 645/1876 [02:56<05:30,  3.72it/s]
# Contours processed:  34%|███▍      | 646/1876 [02:57<05:30,  3.73it/s]
# Contours processed:  34%|███▍      | 647/1876 [02:57<05:28,  3.74it/s]
# Contours processed:  35%|███▍      | 648/1876 [02:57<05:28,  3.74it/s]
# Contours processed:  35%|███▍      | 649/1876 [02:57<05:28,  3.74it/s]
# Contours processed:  35%|███▍      | 650/1876 [02:58<05:29,  3.73it/s]
# Contours processed:  35%|███▍      | 651/1876 [02:58<05:29,  3.71it/s]
# Contours processed:  35%|███▍      | 652/1876 [02:58<05:30,  3.70it/s]
# Contours processed:  35%|███▍      | 653/1876 [02:59<05:30,  3.71it/s]
# Contours processed:  35%|███▍      | 654/1876 [02:59<05:29,  3.71it/s]
# Contours processed:  35%|███▍      | 655/1876 [02:59<05:28,  3.72it/s]
# Contours processed:  35%|███▍      | 656/1876 [02:59<05:29,  3.70it/s]
# Contours processed:  35%|███▌      | 657/1876 [03:00<05:28,  3.71it/s]
# Contours processed:  35%|███▌      | 658/1876 [03:00<05:27,  3.72it/s]
# Contours processed:  35%|███▌      | 659/1876 [03:00<05:27,  3.72it/s]
# Contours processed:  35%|███▌      | 660/1876 [03:00<05:26,  3.73it/s]
# Contours processed:  35%|███▌      | 661/1876 [03:01<05:32,  3.66it/s]
# Contours processed:  35%|███▌      | 662/1876 [03:01<05:39,  3.58it/s]
# Contours processed:  35%|███▌      | 663/1876 [03:01<05:38,  3.58it/s]
# Contours processed:  35%|███▌      | 664/1876 [03:02<05:35,  3.61it/s]
# Contours processed:  35%|███▌      | 665/1876 [03:02<05:32,  3.64it/s]
# Contours processed:  36%|███▌      | 666/1876 [03:02<05:30,  3.66it/s]
# Contours processed:  36%|███▌      | 667/1876 [03:02<05:28,  3.68it/s]
# Contours processed:  36%|███▌      | 668/1876 [03:03<05:27,  3.69it/s]
# Contours processed:  36%|███▌      | 669/1876 [03:03<05:26,  3.69it/s]
# Contours processed:  36%|███▌      | 670/1876 [03:03<05:46,  3.48it/s]
# Contours processed:  36%|███▌      | 671/1876 [03:03<05:42,  3.52it/s]
# Contours processed:  36%|███▌      | 672/1876 [03:04<05:35,  3.58it/s]
# Contours processed:  36%|███▌      | 673/1876 [03:04<05:32,  3.62it/s]
# Contours processed:  36%|███▌      | 674/1876 [03:04<05:29,  3.65it/s]
# Contours processed:  36%|███▌      | 675/1876 [03:05<05:28,  3.66it/s]
# Contours processed:  36%|███▌      | 676/1876 [03:05<05:26,  3.68it/s]
# ...
# Contours processed:  89%|████████▊ | 1663/1876 [07:44<01:03,  3.35it/s]
# Contours processed:  89%|████████▊ | 1664/1876 [07:44<01:03,  3.35it/s]
# Contours processed:  89%|████████▉ | 1665/1876 [07:44<01:03,  3.34it/s]
# Contours processed:  89%|████████▉ | 1666/1876 [07:45<01:02,  3.34it/s]
# Contours processed:  89%|████████▉ | 1667/1876 [07:45<01:02,  3.33it/s]
# Contours processed:  89%|████████▉ | 1668/1876 [07:45<01:02,  3.32it/s]
# Contours processed:  89%|████████▉ | 1669/1876 [07:46<01:02,  3.33it/s]
# Contours processed:  89%|████████▉ | 1670/1876 [07:46<01:01,  3.33it/s]
# Contours processed:  89%|████████▉ | 1671/1876 [07:46<01:01,  3.34it/s]
# Contours processed:  89%|████████▉ | 1672/1876 [07:46<01:01,  3.34it/s]
# Contours processed:  89%|████████▉ | 1673/1876 [07:47<01:00,  3.34it/s]
# Contours processed:  89%|████████▉ | 1674/1876 [07:47<01:00,  3.33it/s]
# Contours processed:  89%|████████▉ | 1675/1876 [07:47<01:00,  3.33it/s]
# Contours processed:  89%|████████▉ | 1676/1876 [07:48<01:00,  3.32it/s]
# Contours processed:  89%|████████▉ | 1677/1876 [07:48<01:00,  3.29it/s]
# Contours processed:  89%|████████▉ | 1678/1876 [07:48<00:59,  3.32it/s]
# Contours processed:  89%|████████▉ | 1679/1876 [07:49<00:59,  3.30it/s]
# Contours processed:  90%|████████▉ | 1680/1876 [07:49<01:00,  3.26it/s]
# Contours processed:  90%|████████▉ | 1681/1876 [07:49<01:00,  3.24it/s]
# Contours processed:  90%|████████▉ | 1682/1876 [07:49<00:59,  3.24it/s]
# Contours processed:  90%|████████▉ | 1683/1876 [07:50<00:59,  3.26it/s]
# Contours processed:  90%|████████▉ | 1684/1876 [07:50<00:58,  3.29it/s]
# Contours processed:  90%|████████▉ | 1685/1876 [07:50<00:57,  3.30it/s]
# Contours processed:  90%|████████▉ | 1686/1876 [07:51<00:57,  3.32it/s]
# Contours processed:  90%|████████▉ | 1687/1876 [07:51<00:56,  3.32it/s]
# Contours processed:  90%|████████▉ | 1688/1876 [07:51<00:56,  3.34it/s]
# Contours processed:  90%|█████████ | 1689/1876 [07:52<00:56,  3.34it/s]
# Contours processed:  90%|█████████ | 1690/1876 [07:52<00:55,  3.36it/s]
# Contours processed:  90%|█████████ | 1691/1876 [07:52<00:54,  3.37it/s]
# Contours processed:  90%|█████████ | 1692/1876 [07:52<00:54,  3.36it/s]
# Contours processed:  90%|█████████ | 1693/1876 [07:53<00:54,  3.35it/s]
# Contours processed:  90%|█████████ | 1694/1876 [07:53<00:54,  3.35it/s]
# Contours processed:  90%|█████████ | 1695/1876 [07:53<00:54,  3.33it/s]
# Contours processed:  90%|█████████ | 1696/1876 [07:54<00:53,  3.34it/s]
# Contours processed:  90%|█████████ | 1697/1876 [07:54<00:53,  3.34it/s]
# Contours processed:  91%|█████████ | 1698/1876 [07:54<00:53,  3.35it/s]
# Contours processed:  91%|█████████ | 1699/1876 [07:55<00:52,  3.35it/s]
# Contours processed:  91%|█████████ | 1700/1876 [07:55<00:52,  3.35it/s]
# Contours processed:  91%|█████████ | 1701/1876 [07:55<00:52,  3.33it/s]
# Contours processed:  91%|█████████ | 1702/1876 [07:55<00:52,  3.32it/s]
# Contours processed:  91%|█████████ | 1703/1876 [07:56<00:51,  3.34it/s]
# Contours processed:  91%|█████████ | 1704/1876 [07:56<00:51,  3.34it/s]
# Contours processed:  91%|█████████ | 1705/1876 [07:56<00:51,  3.35it/s]
# Contours processed:  91%|█████████ | 1706/1876 [07:57<00:50,  3.35it/s]
# Contours processed:  91%|█████████ | 1707/1876 [07:57<00:50,  3.35it/s]
# Contours processed:  91%|█████████ | 1708/1876 [07:57<00:50,  3.35it/s]
# Contours processed:  91%|█████████ | 1709/1876 [07:58<00:49,  3.37it/s]
# Contours processed:  91%|█████████ | 1710/1876 [07:58<00:49,  3.37it/s]
# Contours processed:  91%|█████████ | 1711/1876 [07:58<00:49,  3.36it/s]
# Contours processed:  91%|█████████▏| 1712/1876 [07:58<00:49,  3.35it/s]
# Contours processed:  91%|█████████▏| 1713/1876 [07:59<00:48,  3.34it/s]
# Contours processed:  91%|█████████▏| 1714/1876 [07:59<00:48,  3.34it/s]
# Contours processed:  91%|█████████▏| 1715/1876 [07:59<00:48,  3.32it/s]
# Contours processed:  91%|█████████▏| 1716/1876 [08:00<00:48,  3.32it/s]
# Contours processed:  92%|█████████▏| 1717/1876 [08:00<00:47,  3.32it/s]
# Contours processed:  92%|█████████▏| 1718/1876 [08:00<00:47,  3.35it/s]
# Contours processed:  92%|█████████▏| 1719/1876 [08:01<00:46,  3.34it/s]
# Contours processed:  92%|█████████▏| 1720/1876 [08:01<00:46,  3.34it/s]
# Contours processed:  92%|█████████▏| 1721/1876 [08:01<00:46,  3.35it/s]
# Contours processed:  92%|█████████▏| 1722/1876 [08:01<00:45,  3.36it/s]
# Contours processed:  92%|█████████▏| 1723/1876 [08:02<00:45,  3.36it/s]
# Contours processed:  92%|█████████▏| 1724/1876 [08:02<00:45,  3.36it/s]
# Contours processed:  92%|█████████▏| 1725/1876 [08:02<00:44,  3.37it/s]
# Contours processed:  92%|█████████▏| 1726/1876 [08:03<00:44,  3.36it/s]
# Contours processed:  92%|█████████▏| 1727/1876 [08:03<00:44,  3.36it/s]
# Contours processed:  92%|█████████▏| 1728/1876 [08:03<00:44,  3.35it/s]
# Contours processed:  92%|█████████▏| 1729/1876 [08:04<00:43,  3.36it/s]
# Contours processed:  92%|█████████▏| 1730/1876 [08:04<00:43,  3.35it/s]
# Contours processed:  92%|█████████▏| 1731/1876 [08:04<00:43,  3.36it/s]
# Contours processed:  92%|█████████▏| 1732/1876 [08:04<00:43,  3.31it/s]
# Contours processed:  92%|█████████▏| 1733/1876 [08:05<00:44,  3.21it/s]
# Contours processed:  92%|█████████▏| 1734/1876 [08:05<00:44,  3.20it/s]
# Contours processed:  92%|█████████▏| 1735/1876 [08:05<00:44,  3.19it/s]
# Contours processed:  93%|█████████▎| 1736/1876 [08:06<00:43,  3.23it/s]
# Contours processed:  93%|█████████▎| 1737/1876 [08:06<00:42,  3.26it/s]
# Contours processed:  93%|█████████▎| 1738/1876 [08:06<00:41,  3.30it/s]
# Contours processed:  93%|█████████▎| 1739/1876 [08:07<00:41,  3.31it/s]
# Contours processed:  93%|█████████▎| 1740/1876 [08:07<00:40,  3.32it/s]
# Contours processed:  93%|█████████▎| 1741/1876 [08:07<00:40,  3.34it/s]
# Contours processed:  93%|█████████▎| 1742/1876 [08:07<00:40,  3.33it/s]
# Contours processed:  93%|█████████▎| 1743/1876 [08:08<00:39,  3.33it/s]
# Contours processed:  93%|█████████▎| 1744/1876 [08:08<00:39,  3.36it/s]
# Contours processed:  93%|█████████▎| 1745/1876 [08:08<00:38,  3.36it/s]
# Contours processed:  93%|█████████▎| 1746/1876 [08:09<00:38,  3.35it/s]
# Contours processed:  93%|█████████▎| 1747/1876 [08:09<00:38,  3.32it/s]
# Contours processed:  93%|█████████▎| 1748/1876 [08:09<00:38,  3.34it/s]
# Contours processed:  93%|█████████▎| 1749/1876 [08:10<00:38,  3.34it/s]
# Contours processed:  93%|█████████▎| 1750/1876 [08:10<00:37,  3.33it/s]
# Contours processed:  93%|█████████▎| 1751/1876 [08:10<00:37,  3.33it/s]
# Contours processed:  93%|█████████▎| 1752/1876 [08:10<00:37,  3.34it/s]
# Contours processed:  93%|█████████▎| 1753/1876 [08:11<00:36,  3.34it/s]
# Contours processed:  93%|█████████▎| 1754/1876 [08:11<00:36,  3.33it/s]
# Contours processed:  94%|█████████▎| 1755/1876 [08:11<00:36,  3.35it/s]
# Contours processed:  94%|█████████▎| 1756/1876 [08:12<00:35,  3.36it/s]
# Contours processed:  94%|█████████▎| 1757/1876 [08:12<00:35,  3.35it/s]
# Contours processed:  94%|█████████▎| 1758/1876 [08:12<00:35,  3.35it/s]
# Contours processed:  94%|█████████▍| 1759/1876 [08:13<00:35,  3.34it/s]
# Contours processed:  94%|█████████▍| 1760/1876 [08:13<00:34,  3.33it/s]
# Contours processed:  94%|█████████▍| 1761/1876 [08:13<00:34,  3.32it/s]
# Contours processed:  94%|█████████▍| 1762/1876 [08:13<00:34,  3.33it/s]
# Contours processed:  94%|█████████▍| 1763/1876 [08:14<00:33,  3.33it/s]
# Contours processed:  94%|█████████▍| 1764/1876 [08:14<00:33,  3.33it/s]
# Contours processed:  94%|█████████▍| 1765/1876 [08:14<00:33,  3.32it/s]
# Contours processed:  94%|█████████▍| 1766/1876 [08:15<00:33,  3.31it/s]
# Contours processed:  94%|█████████▍| 1767/1876 [08:15<00:33,  3.25it/s]
# Contours processed:  94%|█████████▍| 1768/1876 [08:15<00:33,  3.21it/s]
# Contours processed:  94%|█████████▍| 1769/1876 [08:16<00:32,  3.26it/s]
# Contours processed:  94%|█████████▍| 1770/1876 [08:16<00:32,  3.28it/s]
# Contours processed:  94%|█████████▍| 1771/1876 [08:16<00:32,  3.26it/s]
# Contours processed:  94%|█████████▍| 1772/1876 [08:17<00:31,  3.27it/s]
# Contours processed:  95%|█████████▍| 1773/1876 [08:17<00:31,  3.28it/s]
# Contours processed:  95%|█████████▍| 1774/1876 [08:17<00:31,  3.28it/s]
# Contours processed:  95%|█████████▍| 1775/1876 [08:17<00:30,  3.30it/s]
# Contours processed:  95%|█████████▍| 1776/1876 [08:18<00:30,  3.32it/s]
# Contours processed:  95%|█████████▍| 1777/1876 [08:18<00:29,  3.32it/s]
# Contours processed:  95%|█████████▍| 1778/1876 [08:18<00:29,  3.33it/s]
# Contours processed:  95%|█████████▍| 1779/1876 [08:19<00:29,  3.34it/s]
# Contours processed:  95%|█████████▍| 1780/1876 [08:19<00:28,  3.31it/s]
# Contours processed:  95%|█████████▍| 1781/1876 [08:19<00:29,  3.26it/s]
# Contours processed:  95%|█████████▍| 1782/1876 [08:20<00:28,  3.26it/s]
# Contours processed:  95%|█████████▌| 1783/1876 [08:20<00:28,  3.28it/s]
# Contours processed:  95%|█████████▌| 1784/1876 [08:20<00:28,  3.26it/s]
# Contours processed:  95%|█████████▌| 1785/1876 [08:21<00:29,  3.13it/s]
# Contours processed:  95%|█████████▌| 1786/1876 [08:21<00:29,  3.06it/s]
# Contours processed:  95%|█████████▌| 1787/1876 [08:21<00:29,  3.04it/s]
# Contours processed:  95%|█████████▌| 1788/1876 [08:22<00:28,  3.04it/s]
# Contours processed:  95%|█████████▌| 1789/1876 [08:22<00:27,  3.12it/s]
# Contours processed:  95%|█████████▌| 1790/1876 [08:22<00:27,  3.17it/s]
# Contours processed:  95%|█████████▌| 1791/1876 [08:22<00:26,  3.18it/s]
# Contours processed:  96%|█████████▌| 1792/1876 [08:23<00:26,  3.16it/s]
# Contours processed:  96%|█████████▌| 1793/1876 [08:23<00:25,  3.21it/s]
# Contours processed:  96%|█████████▌| 1794/1876 [08:23<00:25,  3.24it/s]
# Contours processed:  96%|█████████▌| 1795/1876 [08:24<00:24,  3.26it/s]
# Contours processed:  96%|█████████▌| 1796/1876 [08:24<00:24,  3.29it/s]
# Contours processed:  96%|█████████▌| 1797/1876 [08:24<00:23,  3.29it/s]
# Contours processed:  96%|█████████▌| 1798/1876 [08:25<00:23,  3.30it/s]
# Contours processed:  96%|█████████▌| 1799/1876 [08:25<00:23,  3.30it/s]
# Contours processed:  96%|█████████▌| 1800/1876 [08:25<00:22,  3.31it/s]
# Contours processed:  96%|█████████▌| 1801/1876 [08:25<00:22,  3.31it/s]
# Contours processed:  96%|█████████▌| 1802/1876 [08:26<00:22,  3.30it/s]
# Contours processed:  96%|█████████▌| 1803/1876 [08:26<00:22,  3.31it/s]
# Contours processed:  96%|█████████▌| 1804/1876 [08:26<00:21,  3.32it/s]
# Contours processed:  96%|█████████▌| 1805/1876 [08:27<00:21,  3.29it/s]
# Contours processed:  96%|█████████▋| 1806/1876 [08:27<00:21,  3.26it/s]
# Contours processed:  96%|█████████▋| 1807/1876 [08:27<00:21,  3.25it/s]
# Contours processed:  96%|█████████▋| 1808/1876 [08:28<00:21,  3.24it/s]
# Contours processed:  96%|█████████▋| 1809/1876 [08:28<00:20,  3.26it/s]
# Contours processed:  96%|█████████▋| 1810/1876 [08:28<00:20,  3.29it/s]
# Contours processed:  97%|█████████▋| 1811/1876 [08:29<00:19,  3.32it/s]
# Contours processed:  97%|█████████▋| 1812/1876 [08:29<00:19,  3.32it/s]
# Contours processed:  97%|█████████▋| 1813/1876 [08:29<00:18,  3.34it/s]
# Contours processed:  97%|█████████▋| 1814/1876 [08:29<00:18,  3.35it/s]
# Contours processed:  97%|█████████▋| 1815/1876 [08:30<00:18,  3.34it/s]
# Contours processed:  97%|█████████▋| 1816/1876 [08:30<00:17,  3.35it/s]
# Contours processed:  97%|█████████▋| 1817/1876 [08:30<00:17,  3.35it/s]
# Contours processed:  97%|█████████▋| 1818/1876 [08:31<00:17,  3.36it/s]
# Contours processed:  97%|█████████▋| 1819/1876 [08:31<00:17,  3.34it/s]
# Contours processed:  97%|█████████▋| 1820/1876 [08:31<00:16,  3.35it/s]
# Contours processed:  97%|█████████▋| 1821/1876 [08:32<00:16,  3.35it/s]
# Contours processed:  97%|█████████▋| 1822/1876 [08:32<00:16,  3.34it/s]
# Contours processed:  97%|█████████▋| 1823/1876 [08:32<00:15,  3.34it/s]
# Contours processed:  97%|█████████▋| 1824/1876 [08:32<00:15,  3.36it/s]
# Contours processed:  97%|█████████▋| 1825/1876 [08:33<00:15,  3.35it/s]
# Contours processed:  97%|█████████▋| 1826/1876 [08:33<00:14,  3.35it/s]
# Contours processed:  97%|█████████▋| 1827/1876 [08:33<00:14,  3.34it/s]
# Contours processed:  97%|█████████▋| 1828/1876 [08:34<00:14,  3.35it/s]
# Contours processed:  97%|█████████▋| 1829/1876 [08:34<00:14,  3.33it/s]
# Contours processed:  98%|█████████▊| 1830/1876 [08:34<00:13,  3.35it/s]
# Contours processed:  98%|█████████▊| 1831/1876 [08:35<00:13,  3.35it/s]
# Contours processed:  98%|█████████▊| 1832/1876 [08:35<00:13,  3.34it/s]
# Contours processed:  98%|█████████▊| 1833/1876 [08:35<00:12,  3.35it/s]
# Contours processed:  98%|█████████▊| 1834/1876 [08:35<00:12,  3.35it/s]
# Contours processed:  98%|█████████▊| 1835/1876 [08:36<00:12,  3.35it/s]
# Contours processed:  98%|█████████▊| 1836/1876 [08:36<00:11,  3.35it/s]
# Contours processed:  98%|█████████▊| 1837/1876 [08:36<00:11,  3.35it/s]
# Contours processed:  98%|█████████▊| 1838/1876 [08:37<00:11,  3.29it/s]
# Contours processed:  98%|█████████▊| 1839/1876 [08:37<00:11,  3.25it/s]
# Contours processed:  98%|█████████▊| 1840/1876 [08:37<00:11,  3.20it/s]
# Contours processed:  98%|█████████▊| 1841/1876 [08:38<00:10,  3.24it/s]
# Contours processed:  98%|█████████▊| 1842/1876 [08:38<00:10,  3.18it/s]
# Contours processed:  98%|█████████▊| 1843/1876 [08:38<00:10,  3.24it/s]
# Contours processed:  98%|█████████▊| 1844/1876 [08:38<00:09,  3.27it/s]
# Contours processed:  98%|█████████▊| 1845/1876 [08:39<00:09,  3.29it/s]
# Contours processed:  98%|█████████▊| 1846/1876 [08:39<00:09,  3.30it/s]
# Contours processed:  98%|█████████▊| 1847/1876 [08:39<00:08,  3.30it/s]
# Contours processed:  99%|█████████▊| 1848/1876 [08:40<00:08,  3.31it/s]
# Contours processed:  99%|█████████▊| 1849/1876 [08:40<00:08,  3.31it/s]
# Contours processed:  99%|█████████▊| 1850/1876 [08:40<00:07,  3.32it/s]
# Contours processed:  99%|█████████▊| 1851/1876 [08:41<00:07,  3.33it/s]
# Contours processed:  99%|█████████▊| 1852/1876 [08:41<00:07,  3.29it/s]
# Contours processed:  99%|█████████▉| 1853/1876 [08:41<00:06,  3.33it/s]
# Contours processed:  99%|█████████▉| 1854/1876 [08:42<00:06,  3.28it/s]
# Contours processed:  99%|█████████▉| 1855/1876 [08:42<00:06,  3.29it/s]
# Contours processed:  99%|█████████▉| 1856/1876 [08:42<00:06,  3.31it/s]
# Contours processed:  99%|█████████▉| 1857/1876 [08:42<00:05,  3.32it/s]
# Contours processed:  99%|█████████▉| 1858/1876 [08:43<00:05,  3.33it/s]
# Contours processed:  99%|█████████▉| 1859/1876 [08:43<00:05,  3.28it/s]
# Contours processed:  99%|█████████▉| 1860/1876 [08:43<00:04,  3.30it/s]
# Contours processed:  99%|█████████▉| 1861/1876 [08:44<00:04,  3.32it/s]
# Contours processed:  99%|█████████▉| 1862/1876 [08:44<00:04,  3.32it/s]
# Contours processed:  99%|█████████▉| 1863/1876 [08:44<00:03,  3.33it/s]
# Contours processed:  99%|█████████▉| 1864/1876 [08:45<00:03,  3.34it/s]
# Contours processed:  99%|█████████▉| 1865/1876 [08:45<00:03,  3.35it/s]
# Contours processed:  99%|█████████▉| 1866/1876 [08:45<00:02,  3.34it/s]
# Contours processed: 100%|█████████▉| 1867/1876 [08:45<00:02,  3.35it/s]
# Contours processed: 100%|█████████▉| 1868/1876 [08:46<00:02,  3.34it/s]
# Contours processed: 100%|█████████▉| 1869/1876 [08:46<00:02,  3.34it/s]
# Contours processed: 100%|█████████▉| 1870/1876 [08:46<00:01,  3.35it/s]
# Contours processed: 100%|█████████▉| 1871/1876 [08:47<00:01,  3.34it/s]
# Contours processed: 100%|█████████▉| 1872/1876 [08:47<00:01,  3.33it/s]
# Contours processed: 100%|█████████▉| 1873/1876 [08:47<00:00,  3.33it/s]
# Contours processed: 100%|█████████▉| 1874/1876 [08:48<00:00,  3.33it/s]
# Contours processed: 100%|█████████▉| 1875/1876 [08:48<00:00,  3.32it/s]
# Contours processed: 100%|██████████| 1876/1876 [08:48<00:00,  3.55it/s]
#
# Contours processed:   0%|          | 0/1876 [00:00<?, ?it/s]
# Contours processed:  35%|███▍      | 650/1876 [00:00<00:00, 1799.60it/s]
# Contours processed:  38%|███▊      | 704/1876 [00:01<00:09, 122.75it/s]
# Contours processed:  41%|████      | 771/1876 [00:02<00:07, 142.85it/s]
# Contours processed:  58%|█████▊    | 1093/1876 [00:02<00:04, 192.20it/s]
# Contours processed:  61%|██████    | 1147/1876 [00:03<00:06, 119.48it/s]
# Contours processed:  63%|██████▎   | 1187/1876 [00:04<00:10, 68.14it/s]
# Contours processed: 100%|██████████| 1876/1876 [00:04<00:00, 390.33it/s][A
